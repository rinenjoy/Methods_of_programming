# %% [markdown]
# - реализуйте сущность CitySystemConnector, которая будет имитировать получение изменения режима, реализуйте взаимодействие CitySystemConnector и ControlSystem (понадобится доработать политики безопасности). Например, изменение длительности зелёного по направлениям или отключение светофора (перевод перекрёстка в режим нерегулируемого)- реализуйте сущность CitySystemConnector, которая будет имитировать получение изменения режима, реализуйте взаимодействие CitySystemConnector и ControlSystem (понадобится доработать политики безопасности). Например, изменение длительности зелёного по направлениям или отключение светофора (перевод перекрёстка в режим нерегулируемого)# Кибериммунный подход к разработке. Учебный пример "Светофор"
#
# ## Об авторе
#
# Этот блокнот разработан для вас Сергеем Соболевым, sergey.p.sobolev@kaspersky.com
#
# Больше информации о кибериммунном подходе можно найти на странице https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
#
# Подписывайтесь на телеграм-канал @learning_cyberimmunity (https://t.me/learning_cyberimmunity)
#
# Обучающие видео на тему кибериммунного подхода вы можете найти на youtube канале https://www.youtube.com/@learning_cyberimmunity/

# %% [markdown]
# ## О примере
#
# Светофор - это, на первый взгляд, очень простая система, но она оказывает критическое влияние на безопасность дорожного движения.
# Применим идеи конструктивной безопасности к архитектуре и реализации прототипа светофора. За отправную точку возьмём [код базового примера](https://colab.research.google.com/github/sergey-sobolev/cyberimmune-systems-basic-demo-notebook01/blob/main/cyberimmunity-basics.ipynb) и немного его переработаем.
#
# Для переработки будем использовать описание архитектуры решения, которое обсуждалось на занятии.

# %% [markdown]
# ## Простая реализация выбранной политики архитектуры
#
# Будем использовать политику архитектуры, показанную на рис. 1.
#
# ![Рис. 1. Политика архитектуры](images/tl-archpol-0.02.png)
#
# Рис. 1. Политика архитектуры светофора
#
# 1. Создадим функциональные компоненты (сущности 1-4) и монитор безопасности, который будет контролировать их взаимодействие, в том числе реализовывать контроль конфигураций светофора (сущность №5 на архитектурной диаграмме)
# 2. Определим политики безопасности
# 3. Сымитируем запрос на изменение режима для проверки работы всех элементов
#
# - В качестве интерфейса взаимодействия используем очереди сообщений, у каждой сущности есть своя «персональная» очередь, ассоциированная с ней
# - Компоненты 1-4 отправляют сообщения только в очередь monitor сущности SecurityMonitor
# - SecurityMonitor проверяет сообщения на соответствие политикам безопасности, в случае положительного решения перенаправляет сообщение в очередь соответствующей сущности
#
# В коде назовём сущности следующим образом
# 1. Связь - CitySystemConnector
# 2. Система управления светофора - ControlSystem
# 3. Управление светодиодами - LightsGPIO
# 4. Система диагностики - SelfDiagnosticsSystem
#
# Логику контроля режимов светофора (компонент №5 на рис. 1) реализуем в виде политик безопасности в мониторе безопасности
#
# ![Рис. 2. Политика архитектуры с именами классов](images/tl-archpol-code.png)
#
# Рис. 2. Политика архитектуры с именами классов

# %% [markdown]
# Очередь событий для монитора безопасности: все запросы от сущностей друг к другу должны отправляться только в неё

# %%
from multiprocessing import Queue

#средний
from multiprocessing import Event
shutdown_event = Event()



monitor_events_queue = Queue()

# %% [markdown]
# Зафиксируем формат сообщений

# %%
from dataclasses import dataclass


@dataclass
class Event:
    source: str       # отправитель
    destination: str  # получатель
    operation: str    # чего хочет (запрашиваемое действие)
    parameters: str   # с какими параметрами

# %% [markdown]
# ### Монитор безопасности

# %% [markdown]
# Ниже в методе _check_policies можно увидеть пример политики безопасности:
#
# ```python
# if event.source == "ControlSystem" \
#         and event.destination == "LightsGPIO" \
#         and event.operation == "set_mode" \
#         and self._check_mode(event.operation):
#     authorized = True
# ```
#
# в этом примере проверяется отправитель сообщения, получатель, запрашиваемая операция и даже параметры операции. Это максимально жёсткий вариант, очевидно, в зависимости от ситуации количество проверок можно уменьшить.
#
# А пока это место для экспериментов, как можно из монитора безопасности заблокировать взаимодействие между сущностями.

# %%
from multiprocessing import Queue, Process
from multiprocessing.queues import Empty
import json

# формат управляющих команд для монитора
@dataclass
class ControlEvent:
    operation: str

# список разрешенных сочетаний сигналов светофора
# любые сочетания, отсутствующие в этом списке, запрещены
traffic_lights_allowed_configurations = [
    {"direction_1": "red", "direction_2": "green"},
    {"direction_1": "red", "direction_2": "red"},    
    {"direction_1": "red", "direction_2": "yellow"},    
    {"direction_1": "yellow", "direction_2": "yellow"},    
    {"direction_1": "off", "direction_2": "off"},
    {"direction_1": "green", "direction_2": "red"},    
    {"direction_1": "green", "direction_2": "yellow"},
    
    {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}, #Новичок

    
    #средний
    {"direction_1": "red", "direction_2": "green", "left_arrow": "green", "right_arrow": "off"},
    {"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "green"},
    {"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"},


    {"direction_1": "red", "direction_2": "red", "left_arrow": "green", "right_arrow": "off"},    
    {"direction_1": "red", "direction_2": "red", "left_arrow": "off", "right_arrow": "green"},  
    {"direction_1": "red", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"},    


    {"direction_1": "red", "direction_2": "yellow", "left_arrow": "green", "right_arrow": "off"},    
    {"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "green"},    
    {"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"},    


    {"direction_1": "yellow", "direction_2": "yellow", "left_arrow": "green", "right_arrow": "off"},    
    {"direction_1": "yellow", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "green"},    
    {"direction_1": "yellow", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"},    


    {"direction_1": "off", "direction_2": "off", "left_arrow": "green", "right_arrow": "off"},
    {"direction_1": "off", "direction_2": "off", "left_arrow": "off", "right_arrow": "green"},
    {"direction_1": "off", "direction_2": "off", "left_arrow": "off", "right_arrow": "off"},


    {"direction_1": "green", "direction_2": "red", "left_arrow": "green", "right_arrow": "off"},    
    {"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "green"},    
    {"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"},    

    {"direction_1": "green", "direction_2": "yellow", "left_arrow": "green", "right_arrow": "off"},
    {"direction_1": "green", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "green"},
    {"direction_1": "green", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"},

    
    {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking", "left_arrow": "green", "right_arrow": "off"}, 
    {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking", "left_arrow": "off", "right_arrow": "green"}, 
    {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking", "left_arrow": "off", "right_arrow": "off"}, 


]


# Класс, реализующий поведение монитора безопасности
class Monitor(Process):

    def __init__(self, events_q: Queue):
        # вызываем конструктор базового класса
        super().__init__()
        self._events_q = events_q  # очередь событий для монитора (входящие сообщения)
        self._control_q = Queue()  # очередь управляющих команд (например, для остановки монитора)
        self._entity_queues = {}   # словарь очередей известных монитору сущностей
        self._force_quit = False   # флаг завершения работы монитора

    # регистрация очереди новой сущности
    def add_entity_queue(self, entity_id: str, queue: Queue):
        print(f"[монитор] регистрируем сущность {entity_id}")
        self._entity_queues[entity_id] = queue

    def _check_mode(self, mode_str: str) -> bool:
        mode_ok = False
        try:
            # извлечём структуру из строки, в случае ошибки запретим изменение режима
            mode = json.loads(mode_str)
            # проверим входит ли запрашиваемый режим в список разрешённых
            print(f"[монитор] проверяем конфигурацию {mode}")
            if mode in traffic_lights_allowed_configurations:
                # такой режим найден, можно активировать
                mode_ok = True
        except:
            mode_ok = False
        return mode_ok

    # проверка политик безопасности        
    def _check_policies(self, event):
        print(f'[монитор] обрабатываем событие {event}')

        # default deny: всё, что не разрешено, запрещено по умолчанию!
        authorized = False

        # проверка на входе, что это экземпляр класса Event, 
        # т.е. имеет ожидаемый формат
        if not isinstance(event, Event):
            return False

        # 
        #  политики безопасности
        #

        # пример политики безопасности
        if event.source == "ControlSystem" \
                and event.destination == "LightsGPIO" \
                and event.operation == "set_mode" \
                and self._check_mode(event.parameters):
            authorized = True
 
    
        #Средний SelfDiagnostics новый класс 
        if event.source == "LightsGPIO" \
                and event.destination == "SelfDiagnostics" \
                and event.operation == "status":
            authorized = True
            
            
            
        # Продвинутый уровень
        if event.source == "CitySystemConnector" \
                and event.destination == "ControlSystem" \
                and event.operation == "update_timings":
            authorized = True

        if event.source == "CitySystemConnector" \
                and event.destination == "ControlSystem" \
                and event.operation == "emergency_mode":
            authorized = True

        if event.source == "ControlSystem" \
                and event.destination == "CitySystemConnector" \
                and event.operation == "system_status":
            authorized = True
        
        
        # передаем статус самодиагностики в город
        if event.source == "SelfDiagnostics" \
                and event.destination == "CitySystemConnector" \
                and event.operation == "diagnostics_status":
            authorized = True

        
        
        if authorized is False:
            print("[монитор] событие не разрешено политиками безопасности")
        return authorized

    # выполнение разрешённого запроса
    # метод должен вызываться только после проверки политик безопасности
    def _proceed(self, event):
        print(f'[монитор] отправляем запрос {event}')
        try:
            # найдём очередь получателя события
            dst_q: Queue = self._entity_queues[event.destination]
            # и положим запрос в эту очередь
            dst_q.put(event)
        except  Exception as e:
            # например, запрос пришёл от или для неизвестной сущности
            print(f"[монитор] ошибка выполнения запроса {e}")

    # основной код работы монитора безопасности    
    def run(self):
        print('[монитор] старт')

        # в цикле проверяет наличие новых событий, 
        # выход из цикла по флагу _force_quit
        while self._force_quit is False:
            event = None
            try:
                # ожидание сделано неблокирующим, 
                # чтобы можно было завершить работу монитора, 
                # не дожидаясь нового сообщения
                event = self._events_q.get_nowait()
                # сюда попадаем только в случае получение события,
                # теперь нужно проверить политики безопасности
                authorized = self._check_policies(event)
                if authorized:
                    # если политиками запрос авторизован - выполняем
                    self._proceed(event)
            except Empty:
                # сюда попадаем, если новых сообщений ещё нет,
                # в таком случае немного подождём
                sleep(0.5)
            except Exception as e:
                # что-то пошло не так, выведем сообщение об ошибке
                print(f"[монитор] ошибка обработки {e}, {event}")
            self._check_control_q()
        print('[монитор] завершение работы')

    # запрос на остановку работы монитора безопасности для завершения работы
    # может вызываться вне процесса монитора
    def stop(self):
        # поскольку монитор работает в отдельном процессе,
        # запрос помещается в очередь, которая проверяется из процесса монитора
        request = ControlEvent(operation='stop')
        self._control_q.put(request)

    # проверка наличия новых управляющих команд
    def _check_control_q(self):
        try:
            request: ControlEvent = self._control_q.get_nowait()
            print(f"[монитор] проверяем запрос {request}")
            if isinstance(request, ControlEvent) and request.operation == 'stop':
                # поступил запрос на остановку монитора, поднимаем "красный флаг"
                self._force_quit = True
        except Empty:
            # никаких команд не поступило, ну и ладно
            pass

# %% [markdown]
# ### Сущность ControlSystem
#
# Эта сущность отправляет сообщение для другой сущности (LightsGPIO)

# %%
from multiprocessing import Queue, Process
import json


class ControlSystem(Process):

    def __init__(self, monitor_queue: Queue, shutdown_event):
        # вызываем конструктор базового класса
        super().__init__()
        # мы знаем только очередь монитора безопасности для взаимодействия с другими сущностями
        # прямая отправка сообщений в другую сущность запрещена в концепции FLASK
        self.monitor_queue = monitor_queue
        # создаём собственную очередь, в которую монитор сможет положить сообщения для этой сущности
        self._own_queue = Queue()

        
        #средний
        self.shutdown_event = shutdown_event

        
        #Продвинутфй
        self.green_time_dir1 = 10
        self.green_time_dir2 = 15
        self.yellow_time = 2
        #аварийный
        self.emergency_mode = False

        
        
    # выдаёт собственную очередь для взаимодействия
    def entity_queue(self):
        return self._own_queue
    
    
#
#     # основной код сущности. Для "Новичок"
#     def run(self):        
#         print(f'[{self.__class__.__name__}] старт')
#         print(f'[{self.__class__.__name__}] отправляем тестовый запрос')

#         mode = {"direction_1": "green", "direction_2": "green"} #Новичок

#         # запрос для сущности WorkerB - "скажи hello"
#         event = Event(source=self.__class__.__name__,
#                       destination='LightsGPIO',
#                       operation='set_mode',
#                       parameters=json.dumps(mode)
#                       )
# 
    
    
#     # ноовая сущность Средний
#     def run(self):        
#         print(f'[{self.__class__.__name__}] старт')
#         print(f'[{self.__class__.__name__}] отправляем тестовый запрос')

#         mode = {"direction_1": "red", "direction_2": "red", "left_arrow": "green", "right_arrow": "off"}

#         while not self.shutdown_event.is_set():
#             try:
#                 event = Event(
#                     source="ControlSystem",
#                     destination="LightsGPIO",
#                     operation="set_mode",
#                     parameters=json.dumps(mode)
#                 )

#                 print(f'[{self.__class__.__name__}] отправляем режим')
#                 self.monitor_queue.put(event)

#                 sleep(5)

#             except Exception as e:
#                 print("[ControlSystem] ошибка:", e)
#                 sleep(1)


    # безопасный sleep Треий уровень
    def _sleep_with_shutdown(self, seconds):
        for _ in range(seconds):
            if self.shutdown_event.is_set():
                break
            sleep(1)

    # ноовая сущность ТРЕТИЙ лэвл
    def run(self):
        print(f'[{self.__class__.__name__}] старт')
        print(f'[{self.__class__.__name__}] отправляем тестовый запрос')  

        while not self.shutdown_event.is_set():
            
            # команды города
            while not self._own_queue.empty():
                event = self._own_queue.get()

                if event.operation == "update_timings":
                    data = json.loads(event.parameters)

                    self.green_time_dir1 = data["green_time_dir1"]
                    self.green_time_dir2 = data["green_time_dir2"]

                    print(f'[{self.__class__.__name__}] обновлены тайминги:', self.green_time_dir1, self.green_time_dir2)

                elif event.operation == "emergency_mode":
                    data = json.loads(event.parameters)
                    self.emergency_mode = data["enabled"]

                    print(f'[{self.__class__.__name__}] аварийный режим:', self.emergency_mode)
                
            # аварийный режим
            if self.emergency_mode:
                print(f'[{self.__class__.__name__}] мигающий жёлтый режим')

                event = Event(
                    source="ControlSystem",
                    destination="LightsGPIO",
                    operation="set_mode",
                    parameters=json.dumps({
                        "direction_1": "yellow",
                        "direction_2": "yellow",
                        "left_arrow": "off",
                        "right_arrow": "off"
                    })
                )

                self.monitor_queue.put(event)
                
                # отправляем текущий режим в город
                status_event = Event(
                    source="ControlSystem",
                    destination="CitySystemConnector",
                    operation="system_status",
                    parameters=event.parameters
                )
                self.monitor_queue.put(status_event)
                
                self._sleep_with_shutdown(1)
                continue


            # 1 — ЗЕЛЁНЫЙ НАПРАВЛЕНИЕ 1
            print(f'[{self.__class__.__name__}] зелёный направление 1')

            event = Event(
                source="ControlSystem",
                destination="LightsGPIO",
                operation="set_mode",
                parameters=json.dumps({
                    "direction_1": "green",
                    "direction_2": "red",
                    "left_arrow": "off",
                    "right_arrow": "off"
                })
            )

            self.monitor_queue.put(event)
            
            # отправляем текущий режим в город
            status_event = Event(
                source="ControlSystem",
                destination="CitySystemConnector",
                operation="system_status",
                parameters=event.parameters
            )
            self.monitor_queue.put(status_event)

            
            self._sleep_with_shutdown(self.green_time_dir1)

            if self.shutdown_event.is_set():
                break

            # ЖЁЛТЫЙ 1
            print(f'[{self.__class__.__name__}] жёлтый после направления 1')

            event = Event(
                source="ControlSystem",
                destination="LightsGPIO",
                operation="set_mode",
                parameters=json.dumps({
                    "direction_1": "yellow",
                    "direction_2": "red",
                    "left_arrow": "off",
                    "right_arrow": "off"
                })
            )

            self.monitor_queue.put(event)
            
            # отправляем текущий режим в город
            status_event = Event(
                source="ControlSystem",
                destination="CitySystemConnector",
                operation="system_status",
                parameters=event.parameters
            )
            self.monitor_queue.put(status_event)

            
            self._sleep_with_shutdown(self.yellow_time)

            if self.shutdown_event.is_set():
                break

            # 2 — ЗЕЛЁНЫЙ НАПРАВЛЕНИЕ 2
            print(f'[{self.__class__.__name__}] зелёный направление 2')

            event = Event(
                source="ControlSystem",
                destination="LightsGPIO",
                operation="set_mode",
                parameters=json.dumps({
                    "direction_1": "red",
                    "direction_2": "green",
                    "left_arrow": "off",
                    "right_arrow": "off"
                })
            )

            self.monitor_queue.put(event)
            
            # отправляем текущий режим в город
            status_event = Event(
                source="ControlSystem",
                destination="CitySystemConnector",
                operation="system_status",
                parameters=event.parameters
            )
            self.monitor_queue.put(status_event)

            
            self._sleep_with_shutdown(self.green_time_dir2)

            if self.shutdown_event.is_set():
                break

            # ЖЁЛТЫЙ 2
            print(f'[{self.__class__.__name__}] жёлтый после направления 2')

            event = Event(
                source="ControlSystem",
                destination="LightsGPIO",
                operation="set_mode",
                parameters=json.dumps({
                    "direction_1": "red",
                    "direction_2": "yellow",
                    "left_arrow": "off",
                    "right_arrow": "off"
                })
            )

            self.monitor_queue.put(event)
            
            # отправляем текущий режим в город
            status_event = Event(
                source="ControlSystem",
                destination="CitySystemConnector",
                operation="system_status",
                parameters=event.parameters
            )
            self.monitor_queue.put(status_event)

            
            self._sleep_with_shutdown(self.yellow_time)

        print(f'[{self.__class__.__name__}] завершение работы')

# %% [markdown]
# ### Сущность SelfDiagnostics

# %%
class SelfDiagnostics(Process):

    def __init__(self, monitor_queue: Queue, shutdown_event):
        super().__init__()
        self.monitor_queue = monitor_queue
        self._own_queue = Queue()
                
        #средний
        self.shutdown_event = shutdown_event
        

    def entity_queue(self):
        return self._own_queue

    def run(self):
        print(f'[{self.__class__.__name__}] старт')

        while not self.shutdown_event.is_set():
            try:
                event = self._own_queue.get_nowait()

                if event.operation == "status":
                    print(f'[{self.__class__.__name__}] получен статус:', event.parameters)

                    status_event = Event(
                        source="SelfDiagnostics",
                        destination="CitySystemConnector",
                        operation="diagnostics_status",
                        parameters=event.parameters
                    )

                    self.monitor_queue.put(status_event)

            except Empty:
                sleep(1)

# %% [markdown]
# ### Сущность CitySystemConnector

# %%
class CitySystemConnector(Process):

    def __init__(self, monitor_queue: Queue, shutdown_event):
        super().__init__()
        self.monitor_queue = monitor_queue
        self.shutdown_event = shutdown_event
        self._own_queue = Queue()

    def entity_queue(self):
        return self._own_queue

    def run(self):
        print(f'[{self.__class__.__name__}] старт')


        # Через 20 секунд изменить длительность зелёного
        sleep(20)

        if not self.shutdown_event.is_set():
            print(f'[{self.__class__.__name__}] изменение длительности зелёного')

            event = Event(
                source="CitySystemConnector",
                destination="ControlSystem",
                operation="update_timings",
                parameters=json.dumps({
                    "green_time_dir1": 5,
                    "green_time_dir2": 5
                })
            )

            self.monitor_queue.put(event)

        # офф мигающий
        sleep(20)

        if not self.shutdown_event.is_set():
            print(f'[{self.__class__.__name__}] включаем аварийный режим')

            event = Event(
                source="CitySystemConnector",
                destination="ControlSystem",
                operation="emergency_mode",
                parameters=json.dumps({
                    "enabled": True
                })
            )

            self.monitor_queue.put(event)

        # Ждём события от системы
        while not self.shutdown_event.is_set():
            try:
                event = self._own_queue.get_nowait()

                if event.operation == "diagnostics_status":
                    print(f"[CitySystemConnector] Статус диагностики: {event.parameters}")

                elif event.operation == "system_status":
                    mode = json.loads(event.parameters)
                    print(f"[CitySystemConnector] Текущий режим светофора: {mode}")

            except Empty:
                sleep(0.5)

# %% [markdown]
# ### Сущность LightsGPIO
#
# Эта сущность ждёт входящее сообщение в течение заданного периода времени, если получает - обрабатывает и завершает работу или выходит по таймауту.

# %%
from multiprocessing import Queue, Process
from time import sleep


class LightsGPIO(Process):

    def __init__(self, monitor_queue: Queue, shutdown_event):
        # вызываем конструктор базового класса
        super().__init__()
        # мы знаем только очередь монитора безопасности для взаимодействия с другими сущностями
        # прямая отправка сообщений в другую сущность запрещена в концепции FLASK
        self.monitor_queue = monitor_queue
        # создаём собственную очередь, в которую монитор сможет положить сообщения для этой сущности
        self._own_queue = Queue()        
                
        #средний
        self.shutdown_event = shutdown_event


    def entity_queue(self):
        return self._own_queue

    # основной код сущности
    def run(self):        
        print(f'[{self.__class__.__name__}] старт')

        while not self.shutdown_event.is_set():
            try:
                event: Event = self._own_queue.get_nowait()
                
                if event.operation == "set_mode":
                    
                    
                    print(f"[{self.__class__.__name__}] {event.source} запрашивает изменение режима {event.parameters}")
                    print(f"[{self.__class__.__name__}] новый режим: {event.parameters}!")
#                    break
                    status_event = Event(
                        source="LightsGPIO",
                        destination="SelfDiagnostics",
                        operation="status",
                        parameters="OK"
                    )
                
                    self.monitor_queue.put(status_event)

                    
            except Empty:
                sleep(0.5)

#        print(f'[{self.__class__.__name__}] завершение работы')

# %% [markdown]
# ### Инициализируем монитор и сущности

# %%
monitor = Monitor(monitor_events_queue)
control_system = ControlSystem(monitor_events_queue, shutdown_event)
lights_gpio = LightsGPIO(monitor_events_queue, shutdown_event)

#средний
diagnostics = SelfDiagnostics(monitor_events_queue, shutdown_event)

#3-ий
city_connector = CitySystemConnector(monitor_events_queue, shutdown_event)

# %% [markdown]
# регистрируем очереди сущностей в мониторе

# %%
monitor.add_entity_queue(control_system.__class__.__name__, control_system.entity_queue())
monitor.add_entity_queue(lights_gpio.__class__.__name__, lights_gpio.entity_queue())
#средний
monitor.add_entity_queue(diagnostics.__class__.__name__, diagnostics.entity_queue())
#3-ий
monitor.add_entity_queue(city_connector.__class__.__name__, city_connector.entity_queue())
# Out:
# [монитор] регистрируем сущность ControlSystem
# [монитор] регистрируем сущность LightsGPIO
# [монитор] регистрируем сущность SelfDiagnostics
# [монитор] регистрируем сущность CitySystemConnector

# %% [markdown]
# ### Запускаем всё

# %% [markdown]
# Ожидаемая последовательность событий
#
# ![Диаграмма последовательности вызовов](https://www.plantuml.com/plantuml/png/dPBVIiCm6CNlynIvdtk1NSZ02n4KXJr1w886-cUqcR0xgoBpIdoJLgqhtRg-mfStygJPM3js9OLyoPTpVia97ITQn7eU-6o6gZmr4w7c5r6euyYVB18j0ouIxhb6JpIHtZnMUd4JXKf7iPK5RjgJNQlx1vrStbtTMeNVhXZR0VdmV6yQ34QSQjhI5sNcWrE5QMrUgQHlysAUq7oZqcxyq1hbW6KxG8S5KWEBPHMe5MLeOBa6uHd4YWbVSs1JQg1OKktEF3ATSTI2Vk7Os6b6AupGerctn3uM5WWfn_OAxGRGr4OogTtktjCzmt3utyZ2q-fHQBb_JrSEv177oHigRB1E2ChOL1vxfPz8ZWjdBhv9ELn5Bw_vfFf4L2fFlZsEtkBBpNjxWH8mkyHWbbZbC1TCXbCsne1Vxmy0)

# %%
monitor.start()
control_system.start()
lights_gpio.start()
#средний
diagnostics.start()
#3-ий
city_connector.start()

sleep(60)

shutdown_event.set()
# Out:
# [монитор] старт
# [ControlSystem] старт
# [ControlSystem] отправляем тестовый запрос
#
# [LightsGPIO] старт[ControlSystem] зелёный направление 1
# [SelfDiagnostics] старт
# [CitySystemConnector] старт
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] проверяем конфигурацию {'direction_1': 'green', 'direction_2': 'red', 'left_arrow': 'off', 'right_arrow': 'off'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] отправляем запрос Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}
# [LightsGPIO] новый режим: {"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [SelfDiagnostics] получен статус: OK
# [монитор] обрабатываем событие Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [монитор] отправляем запрос Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [ControlSystem] жёлтый после направления 1
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow', 'direction_2': 'red', 'left_arrow': 'off', 'right_arrow': 'off'}
# [монитор] событие не разрешено политиками безопасности
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "yellow", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] отправляем запрос Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "yellow", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [ControlSystem] зелёный направление 2
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] проверяем конфигурацию {'direction_1': 'red', 'direction_2': 'green', 'left_arrow': 'off', 'right_arrow': 'off'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] отправляем запрос Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"}
# [LightsGPIO] новый режим: {"direction_1": "red", "direction_2": "green", "left_arrow": "off", "right_arrow": "off"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [SelfDiagnostics] получен статус: OK
# [монитор] обрабатываем событие Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [монитор] отправляем запрос Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [CitySystemConnector] изменение длительности зелёного
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='update_timings', parameters='{"green_time_dir1": 5, "green_time_dir2": 5}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='update_timings', parameters='{"green_time_dir1": 5, "green_time_dir2": 5}')
# [ControlSystem] жёлтый после направления 2
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] проверяем конфигурацию {'direction_1': 'red', 'direction_2': 'yellow', 'left_arrow': 'off', 'right_arrow': 'off'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] отправляем запрос Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"}
# [LightsGPIO] новый режим: {"direction_1": "red", "direction_2": "yellow", "left_arrow": "off", "right_arrow": "off"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [SelfDiagnostics] получен статус: OK
# [монитор] обрабатываем событие Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [монитор] отправляем запрос Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [ControlSystem] обновлены тайминги: 5 5
# [ControlSystem] зелёный направление 1
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] проверяем конфигурацию {'direction_1': 'green', 'direction_2': 'red', 'left_arrow': 'off', 'right_arrow': 'off'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [монитор] отправляем запрос Event(source='ControlSystem', destination='CitySystemConnector', operation='system_status', parameters='{"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}
# [LightsGPIO] новый режим: {"direction_1": "green", "direction_2": "red", "left_arrow": "off", "right_arrow": "off"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='status', parameters='OK')
# [SelfDiagnostics] получен статус: OK
# [монитор] обрабатываем событие Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')
# [монитор] отправляем запрос Event(source='SelfDiagnostics', destination='CitySystemConnector', operation='diagnostics_status', parameters='OK')

# %% [markdown]
# ### Теперь останавливаем

# %%
monitor.stop()
control_system.join()
lights_gpio.join()

#3-ий
city_connector.join()

monitor.join()

# %% [markdown]
# ## Заключение
#
# В этом блокноте продемонстрирован базовый функционал контролируемого изменения режима работы светофора.
#
# В примере не реализованы некоторые сущности и большая часть логики работы светофора, которую можно предположить по архитектурной диаграмме. Попробуйте сделать это самостоятельно!

# %% [markdown]
# ## Упражнения
#
# Уровень "Новичок"
#
# - в коде ControlSystem измените режим на недопустимый (два зелёных) и выполните все ячейки. Убедитесь, что монитор безопасности заблокировал сообщение, как нарушающее политику безопасности
# - измените политики безопасности так, чтобы был возможен режим "моргающий жёлтый" (yellow_blinking), переводящий перекрёсток в режим нерегулируемого
#
# Уровень "Средней сложности"
#
# - добавьте политики безопасности для доп. секций со стрелками (поворот налево или направо)
# - измените код сущностей, чтобы они не завершали работу после одного сообщения, а работали произвольное время (см. реализацию монитора безопасности)
# - реализуйте сущность само-диагностики (SelfDiagnostics) и отправку сообщений от LightsGPIO (необходимо доработать политики безопасности!)
#
# Уровень "Продвинутый"
#
# - измените код сущности ControlSystem, реализуйте смену режимов по таймеру (заданную длительность зелёного по каждому направлению)
# - реализуйте сущность CitySystemConnector, которая будет имитировать получение изменения режима, реализуйте взаимодействие CitySystemConnector и ControlSystem (понадобится доработать политики безопасности). Например, изменение длительности зелёного по направлениям или отключение светофора (перевод перекрёстка в режим нерегулируемого)
# - реализуйте передачу в компонент CitySystemConnector информации об исправности светофора (статус самодиагностики; текущий режим работы). В компоненте реализуйте вывод в виде сообщений о состоянии системы
