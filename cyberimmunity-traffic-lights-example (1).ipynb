# %% [markdown]
# # Кибериммунный подход к разработке. Учебный пример "Светофор"
#
# ## Об авторе
#
# Этот блокнот разработан для вас Сергеем Соболевым, sergey.p.sobolev@kaspersky.com
#
# Больше информации о кибериммунном подходе можно найти на странице https://github.com/sergey-sobolev/cyberimmune-systems/wiki/%D0%9A%D0%B8%D0%B1%D0%B5%D1%80%D0%B8%D0%BC%D0%BC%D1%83%D0%BD%D0%B8%D1%82%D0%B5%D1%82
#
# Подписывайтесь на телеграм-канал @learning_cyberimmunity (https://t.me/learning_cyberimmunity)
#
# Обучающие видео на тему кибериммунного подхода вы можете найти на youtube канале https://www.youtube.com/@learning_cyberimmunity/

# %% [markdown]
# ## О примере
#
# Светофор - это, на первый взгляд, очень простая система, но она оказывает критическое влияние на безопасность дорожного движения.
# Применим идеи конструктивной безопасности к архитектуре и реализации прототипа светофора. За отправную точку возьмём [код базового примера](https://colab.research.google.com/github/sergey-sobolev/cyberimmune-systems-basic-demo-notebook01/blob/main/cyberimmunity-basics.ipynb) и немного его переработаем.
#
# Для переработки будем использовать описание архитектуры решения, которое обсуждалось на занятии.

# %% [markdown]
# ## Простая реализация выбранной политики архитектуры
#
# Будем использовать политику архитектуры, показанную на рис. 1.
#
# ![Рис. 1. Политика архитектуры](images/tl-archpol-0.02.png)
#
# Рис. 1. Политика архитектуры светофора
#
# 1. Создадим функциональные компоненты (сущности 1-4) и монитор безопасности, который будет контролировать их взаимодействие, в том числе реализовывать контроль конфигураций светофора (сущность №5 на архитектурной диаграмме)
# 2. Определим политики безопасности
# 3. Сымитируем запрос на изменение режима для проверки работы всех элементов
#
# - В качестве интерфейса взаимодействия используем очереди сообщений, у каждой сущности есть своя «персональная» очередь, ассоциированная с ней
# - Компоненты 1-4 отправляют сообщения только в очередь monitor сущности SecurityMonitor
# - SecurityMonitor проверяет сообщения на соответствие политикам безопасности, в случае положительного решения перенаправляет сообщение в очередь соответствующей сущности
#
# В коде назовём сущности следующим образом
# 1. Связь - CitySystemConnector
# 2. Система управления светофора - ControlSystem
# 3. Управление светодиодами - LightsGPIO
# 4. Система диагностики - SelfDiagnosticsSystem
#
# Логику контроля режимов светофора (компонент №5 на рис. 1) реализуем в виде политик безопасности в мониторе безопасности
#
# ![Рис. 2. Политика архитектуры с именами классов](images/tl-archpol-code.png)
#
# Рис. 2. Политика архитектуры с именами классов

# %% [markdown]
# Очередь событий для монитора безопасности: все запросы от сущностей друг к другу должны отправляться только в неё

# %%
from multiprocessing import Queue
monitor_events_queue = Queue()

# %% [markdown]
# Зафиксируем формат сообщений

# %%
from dataclasses import dataclass


@dataclass
class Event:
    source: str       # отправитель
    destination: str  # получатель
    operation: str    # чего хочет (запрашиваемое действие)
    parameters: str   # с какими параметрами

# %% [markdown]
# ### Монитор безопасности

# %% [markdown]
# Ниже в методе _check_policies можно увидеть пример политики безопасности:
#
# ```python
# if event.source == "ControlSystem" \
#         and event.destination == "LightsGPIO" \
#         and event.operation == "set_mode" \
#         and self._check_mode(event.operation):
#     authorized = True
# ```
#
# в этом примере проверяется отправитель сообщения, получатель, запрашиваемая операция и даже параметры операции. Это максимально жёсткий вариант, очевидно, в зависимости от ситуации количество проверок можно уменьшить.
#
# А пока это место для экспериментов, как можно из монитора безопасности заблокировать взаимодействие между сущностями.

# %%
from multiprocessing import Queue, Process
from multiprocessing.queues import Empty
import json
from time import sleep

# формат управляющих команд для монитора
@dataclass
class ControlEvent:
    operation: str

# список разрешенных сочетаний сигналов светофора
# любые сочетания, отсутствующие в этом списке, запрещены
traffic_lights_allowed_configurations = [
    {"direction_1": "red", "direction_2": "green"},
    {"direction_1": "red", "direction_2": "red"},    
    {"direction_1": "red", "direction_2": "yellow"},    
    {"direction_1": "yellow", "direction_2": "yellow"},    
    {"direction_1": "off", "direction_2": "off"},
    {"direction_1": "green", "direction_2": "red"},    
    {"direction_1": "green", "direction_2": "yellow"},
    
    #Easy
    {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'},
    
    #Medium
    {"direction_1": "green_left", "direction_2": "red"},
    {"direction_1": "green_right", "direction_2": "red"},
    {"direction_1": "red", "direction_2": "green_left"},
    {"direction_1": "red", "direction_2": "green_right"},
    
    {"direction_1": "green_left", "direction_2": "green"},
    {"direction_1": "green_right", "direction_2": "green"},
    {"direction_1": "green", "direction_2": "green_left"},
    {"direction_1": "green", "direction_2": "green_right"}
]


# Класс, реализующий поведение монитора безопасности
class Monitor(Process):

    def __init__(self, events_q: Queue):
        # вызываем конструктор базового класса
        super().__init__()
        self._events_q = events_q  # очередь событий для монитора (входящие сообщения)
        self._control_q = Queue()  # очередь управляющих команд (например, для остановки монитора)
        self._entity_queues = {}   # словарь очередей известных монитору сущностей
        self._force_quit = False   # флаг завершения работы монитора

    # регистрация очереди новой сущности
    def add_entity_queue(self, entity_id: str, queue: Queue):
        print(f"[монитор] регистрируем сущность {entity_id}")
        self._entity_queues[entity_id] = queue

    def _check_mode(self, mode_str: str) -> bool:
        mode_ok = False
        try:
            # извлечём структуру из строки, в случае ошибки запретим изменение режима
            mode = json.loads(mode_str)
            # проверим входит ли запрашиваемый режим в список разрешённых
            print(f"[монитор] проверяем конфигурацию {mode}")
            if mode in traffic_lights_allowed_configurations:
                # такой режим найден, можно активировать
                mode_ok = True
        except:
            mode_ok = False
        return mode_ok

    # проверка политик безопасности        
    def _check_policies(self, event):
        print(f'[монитор] обрабатываем событие {event}')

        # default deny: всё, что не разрешено, запрещено по умолчанию!
        authorized = False

        # проверка на входе, что это экземпляр класса Event, 
        # т.е. имеет ожидаемый формат
        if not isinstance(event, Event):
            return False

        # 
        #  политики безопасности
        #

        # пример политики безопасности
        if event.source == "ControlSystem" \
                and event.destination == "LightsGPIO" \
                and event.operation == "set_mode" \
                and self._check_mode(event.parameters):
            authorized = True
        
        #Medium
        if event.source == "LightsGPIO" \
                and event.destination == "SelfDiagnostics" \
                and event.operation in ["mode_changed", "diagnostic_status"]:  # разрешённые операции
            authorized = True
        
        #Advanced
        if event.source == "LightsGPIO" \
                and event.destination == "CitySystemConnector" \
                and event.operation == "mode_changed":
            authorized = True

        if event.source == "SelfDiagnostics" \
                and event.destination == "CitySystemConnector" \
                and event.operation == "health_status":
            authorized = True
    
        if event.source == "CitySystemConnector" \
                and event.destination == "ControlSystem" \
                and event.operation in ["set_green_duration", "set_system_mode"]:
        # Дополнительно можно проверять параметры, но пока пропускаем
            authorized = True

        if authorized is False:
            print("[монитор] событие не разрешено политиками безопасности")
        return authorized

    # выполнение разрешённого запроса
    # метод должен вызываться только после проверки политик безопасности
    def _proceed(self, event):
        print(f'[монитор] отправляем запрос {event}')
        try:
            # найдём очередь получателя события
            dst_q: Queue = self._entity_queues[event.destination]
            # и положим запрос в эту очередь
            dst_q.put(event)
        except  Exception as e:
            # например, запрос пришёл от или для неизвестной сущности
            print(f"[монитор] ошибка выполнения запроса {e}")

    # основной код работы монитора безопасности    
    def run(self):
        print('[монитор] старт')

        # в цикле проверяет наличие новых событий, 
        # выход из цикла по флагу _force_quit
        while self._force_quit is False:
            event = None
            try:
                # ожидание сделано неблокирующим, 
                # чтобы можно было завершить работу монитора, 
                # не дожидаясь нового сообщения
                event = self._events_q.get_nowait()
                # сюда попадаем только в случае получение события,
                # теперь нужно проверить политики безопасности
                authorized = self._check_policies(event)
                if authorized:
                    # если политиками запрос авторизован - выполняем
                    self._proceed(event)
            except Empty:
                # сюда попадаем, если новых сообщений ещё нет,
                # в таком случае немного подождём
                sleep(0.5)
            except Exception as e:
                # что-то пошло не так, выведем сообщение об ошибке
                print(f"[монитор] ошибка обработки {e}, {event}")
            self._check_control_q()
        print('[монитор] завершение работы')

    # запрос на остановку работы монитора безопасности для завершения работы
    # может вызываться вне процесса монитора
    def stop(self):
        # поскольку монитор работает в отдельном процессе,
        # запрос помещается в очередь, которая проверяется из процесса монитора
        request = ControlEvent(operation='stop')
        self._control_q.put(request)

    # проверка наличия новых управляющих команд
    def _check_control_q(self):
        try:
            request: ControlEvent = self._control_q.get_nowait()
            print(f"[монитор] проверяем запрос {request}")
            if isinstance(request, ControlEvent) and request.operation == 'stop':
                # поступил запрос на остановку монитора, поднимаем "красный флаг"
                self._force_quit = True
        except Empty:
            # никаких команд не поступило, ну и ладно
            pass

# %% [markdown]
# ### Сущность ControlSystem
#
# Эта сущность отправляет сообщение для другой сущности (LightsGPIO)

# %%
from multiprocessing import Queue, Process
from multiprocessing.queues import Empty
from time import sleep
import json


class ControlSystem(Process):

    def __init__(self, monitor_queue: Queue):
        # вызываем конструктор базового класса
        super().__init__()
        # мы знаем только очередь монитора безопасности для взаимодействия с другими сущностями
        # прямая отправка сообщений в другую сущность запрещена в концепции FLASK
        self.monitor_queue = monitor_queue
        # создаём собственную очередь, в которую монитор сможет положить сообщения для этой сущности
        self._own_queue = Queue()
        
        #Medium
        self._control_q = Queue()
        self._running = True
        
        #Advanced
        self.green_dur_1 = 5
        self.green_dur_2 = 5
        self.yellow_dur = 2
        
        self.special_mode = None

    # выдаёт собственную очередь для взаимодействия
    def entity_queue(self):
        return self._own_queue
    
    #Medium
    def stop(self):
        self._control_q.put(ControlEvent(operation='stop'))
    
    #Advanced
    def _send_mode(self, mode_dict):
        event = Event(
            source=self.__class__.__name__,
            destination='LightsGPIO',
            operation='set_mode',
            parameters=json.dumps(mode_dict)
        )
        print(f'[{self.__class__.__name__}] отправляем режим {mode_dict}')
        self.monitor_queue.put(event)

    def _wait_with_stop_check(self, seconds):
        steps = int(seconds / 0.2)
        for _ in range(steps):
            if not self._running:
                return False
            try:
                cmd = self._control_q.get_nowait()
                if isinstance(cmd, ControlEvent) and cmd.operation == 'stop':
                    self._running = False
                    return False
            except Empty:
                pass
            self._process_incoming()
            sleep(0.2)
        remainder = seconds - steps * 0.2
        if remainder > 0 and self._running:
            sleep(remainder)
        return self._running

    def _process_incoming(self):
        try:
            event = self._own_queue.get_nowait()
            print(f'[{self.__class__.__name__}] получена команда: {event.operation} {event.parameters}')
            if event.operation == 'set_green_duration':
                params = json.loads(event.parameters)
                if 'direction_1' in params:
                    self.green_dur_1 = params['direction_1']
                if 'direction_2' in params:
                    self.green_dur_2 = params['direction_2']
                print(f'[{self.__class__.__name__}] длительности изменены: d1={self.green_dur_1}, d2={self.green_dur_2}')
            elif event.operation == 'set_system_mode':
                params = json.loads(event.parameters)
                mode = params.get('mode')
                if mode in ['yellow_blinking', 'off', None]:
                    self.special_mode = mode
                    print(f'[{self.__class__.__name__}] установлен специальный режим: {mode}')
            # Можно добавить другие операции
        except Empty:
            pass
    
    def run(self):
        print(f'[{self.__class__.__name__}] старт')
        while self._running:
            self._process_incoming()
            
            if self.special_mode == 'yellow_blinking':
                # Режим мигающего жёлтого: отправляем соответствующий режим и ждём
                self._send_mode({"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"})
                # Ждём 1 секунду (или дольше), но с проверкой команд
                if not self._wait_with_stop_check(1):
                    break
                continue  # возвращаемся в начало цикла, чтобы проверить, не изменился ли special_mode
            elif self.special_mode == 'off':
                # Режим отключения: отправляем off для всех направлений
                self._send_mode({"direction_1": "off", "direction_2": "off"})
                if not self._wait_with_stop_check(1):
                    break
                continue
            else:
            
                if not self._running: break
                self._send_mode({"direction_1": "green", "direction_2": "red"})
                if not self._wait_with_stop_check(self.green_dur_1):
                    break

                if not self._running: break
                self._send_mode({"direction_1": "yellow", "direction_2": "red"})
                if not self._wait_with_stop_check(self.yellow_dur):
                    break

                if not self._running: break
                self._send_mode({"direction_1": "red", "direction_2": "green"})
                if not self._wait_with_stop_check(self.green_dur_2):
                    break

                if not self._running: break
                self._send_mode({"direction_1": "red", "direction_2": "yellow"})
                if not self._wait_with_stop_check(self.yellow_dur):
                    break

        print(f'[{self.__class__.__name__}] завершение работы')
#---------------------------------------------------------------------------------------------------
    #Medium
    #def run(self):
    #    print(f'[{self.__class__.__name__}] старт')

    #    mode = {"direction_1": "red", "direction_2": "green"}

    #    while self._running:

    #        event = Event(
    #            source=self.__class__.__name__,
    #            destination='LightsGPIO',
    #            operation='set_mode',
    #            parameters=json.dumps(mode)
    #        )

    #        print(f'[{self.__class__.__name__}] отправляем режим {mode}')
    #        self.monitor_queue.put(event)

    #        try:
    #            cmd = self._control_q.get_nowait()
    #            if isinstance(cmd, ControlEvent) and cmd.operation == 'stop':
    #                print(f'[{self.__class__.__name__}] получена команда остановки')
    #                self._running = False
    #                break
    #        except Empty:
    #            pass

    #        sleep(3)
#-----------------------------------------------------------------------------------------------
    # основной код сущности
    #def run(self):        
        #print(f'[{self.__class__.__name__}] старт')
        #print(f'[{self.__class__.__name__}] отправляем тестовый запрос')

        #Easy
        #mode = {"direction_1": "green", "direction_2": "green"}
        
        
        #mode = {"direction_1": "red", "direction_2": "green"}

        # запрос для сущности WorkerB - "скажи hello"
        #event = Event(source=self.__class__.__name__,
                      #destination='LightsGPIO',
                      #operation='set_mode',
                      #parameters=json.dumps(mode)
                      #)
        
        #self.monitor_queue.put(event)
        #print(f'[{self.__class__.__name__}] завершение работы')

# %% [markdown]
# ### Сущность LightsGPIO
#
# Эта сущность ждёт входящее сообщение в течение заданного периода времени, если получает - обрабатывает и завершает работу или выходит по таймауту.

# %%
from multiprocessing import Queue, Process
from time import sleep


class LightsGPIO(Process):

    def __init__(self, monitor_queue: Queue):
        # вызываем конструктор базового класса
        super().__init__()
        # мы знаем только очередь монитора безопасности для взаимодействия с другими сущностями
        # прямая отправка сообщений в другую сущность запрещена в концепции FLASK
        self.monitor_queue = monitor_queue
        # создаём собственную очередь, в которую монитор сможет положить сообщения для этой сущности
        self._own_queue = Queue()
        
        #Medium
        self._control_q = Queue()
        self._running = True

    def entity_queue(self):
        return self._own_queue
    
    #Medium
    def stop(self):
        self._control_q.put(ControlEvent(operation='stop'))

    def run(self):
        print(f'[{self.__class__.__name__}] старт')

        while self._running:
            # Обрабатываем входящие сообщения от монитора
            try:
                event: Event = self._own_queue.get_nowait()
                if event.operation == "set_mode":
                    print(f"[{self.__class__.__name__}] {event.source} запрашивает изменение режима {event.parameters}")
                    print(f"[{self.__class__.__name__}] новый режим: {event.parameters}!")
                # Здесь можно добавить обработку других операций
                #Medium
                    notify = Event(
                        source="LightsGPIO",
                        destination="SelfDiagnostics",
                        operation="mode_changed",
                        parameters=event.parameters,
                    )
                    self.monitor_queue.put(notify)
                    
                    notify_city = Event(
                        source="LightsGPIO",
                        destination="CitySystemConnector",
                        operation="mode_changed",
                        parameters=event.parameters
                    )
                    self.monitor_queue.put(notify_city)
                    
                    status = Event(
                        source="LightsGPIO",
                        destination="SelfDiagnostics",
                        operation="diagnostic_status",
                        parameters="OK",
                    )
                    self.monitor_queue.put(status)
                    
                    #Advanced
                    city_event = Event(
                        source="LightsGPIO",
                        destination="CitySystemConnector",
                        operation="mode_changed",
                        parameters=event.parameters
                    )
                    self.monitor_queue.put(city_event)
            except Empty:
                pass

            # Проверяем управляющую очередь
            try:
                cmd = self._control_q.get_nowait()
                if isinstance(cmd, ControlEvent) and cmd.operation == 'stop':
                    print(f'[{self.__class__.__name__}] получена команда остановки')
                    self._running = False
                    break
            except Empty:
                pass

            sleep(0.2)  # небольшая задержка

        print(f'[{self.__class__.__name__}] завершение работы')

    # основной код сущности
    #def run(self):        
        #print(f'[{self.__class__.__name__}] старт')
        #attempts = 10
        #while attempts > 0:
            #try:
                #event: Event = self._own_queue.get_nowait()
                #if event.operation == "set_mode":
                    #print(f"[{self.__class__.__name__}] {event.source} запрашивает изменение режима {event.parameters}")
                    #print(f"[{self.__class__.__name__}] новый режим: {event.parameters}!")
                    #break
            #except Empty:
                #sleep(0.2)
                #attempts -= 1
        #print(f'[{self.__class__.__name__}] завершение работы')

# %% [markdown]
# ### Сущность SelfDiagnostics

# %%
class SelfDiagnostics(Process):

    def __init__(self, monitor_queue: Queue):
        super().__init__()
        self.monitor_queue = monitor_queue
        self._own_queue = Queue()
        self._control_q = Queue()
        self._running = True

    def entity_queue(self):
        return self._own_queue

    def stop(self):
        self._control_q.put(ControlEvent(operation="stop"))

    def run(self):
        print(f'[{self.__class__.__name__}] старт')

        while self._running:

            try:
                event: Event = self._own_queue.get_nowait()

                if event.operation == "mode_changed":
                    print(f'[{self.__class__.__name__}] режим изменён: {event.parameters}')

                if event.operation == "diagnostic_status":
                    print(f'[{self.__class__.__name__}] статус: {event.parameters}')
                    
                    #Advanced
                    health_event = Event(
                        source="SelfDiagnostics",
                        destination="CitySystemConnector",
                        operation="health_status",
                        parameters=event.parameters
                    )
                    #Medium
                    health = Event(
                        source="SelfDiagnostics",
                        destination="CitySystemConnector",
                        operation="health_status",
                        parameters=event.parameters
                    )
                    self.monitor_queue.put(health)
            except Empty:
                pass

            try:
                cmd = self._control_q.get_nowait()
                if isinstance(cmd, ControlEvent) and cmd.operation == "stop":
                    self._running = False
            except Empty:
                pass

            sleep(0.2)

        print(f'[{self.__class__.__name__}] завершение работы')

# %% [markdown]
# ### Сущность CitySystemConnector

# %%
class CitySystemConnector(Process):
    def __init__(self, monitor_queue: Queue):
        super().__init__()
        self.monitor_queue = monitor_queue
        self._own_queue = Queue()
        self._control_q = Queue()
        self._running = True

    def entity_queue(self):
        return self._own_queue

    def stop(self):
        self._control_q.put(ControlEvent(operation='stop'))

    def run(self):
        print(f'[{self.__class__.__name__}] старт')
        cycle = 0
        while self._running:
            # Имитация внешней команды каждые 8 секунд
            # Проверяем управляющую очередь
            try:
                cmd = self._control_q.get_nowait()
                if isinstance(cmd, ControlEvent) and cmd.operation == 'stop':
                    self._running = False
                    break
            except Empty:
                pass

            #Advanced
            try:
                event = self._own_queue.get_nowait()
                if event.operation == "mode_changed":
                    mode = json.loads(event.parameters)
                    print(f"[{self.__class__.__name__}] ПОЛУЧЕН ТЕКУЩИЙ РЕЖИМ: {mode}")
                elif event.operation == "health_status":
                    status = json.loads(event.parameters)
                    print(f"[{self.__class__.__name__}] ПОЛУЧЕН СТАТУС ИСПРАВНОСТИ: {status}")
                else:
                    print(f"[{self.__class__.__name__}] получено неизвестное событие: {event.operation}")
            except Empty:
                pass
            
            cycle += 1
            if cycle % 2 == 1:
                # Первая команда: установить длительности зелёного (например, 3 и 7 секунд)
                command = {
                    'operation': 'set_green_duration',
                    'parameters': json.dumps({'direction_1': 3, 'direction_2': 7})
                }
            else:
                # Вторая команда: перевести в режим мигающего жёлтого (нерегулируемый перекрёсток)
                command = {
                    'operation': 'set_system_mode',
                    'parameters': json.dumps({'mode': 'yellow_blinking'})
                }
                # Можно также отключить светофор: {'mode': 'off'}

            event = Event(
                source=self.__class__.__name__,
                destination='ControlSystem',
                operation=command['operation'],
                parameters=command['parameters']
            )
            print(f'[{self.__class__.__name__}] отправляем команду: {command["operation"]} {command["parameters"]}')
            self.monitor_queue.put(event)

            # Ждём 8 секунд, но с проверкой остановки
            for _ in range(40):  # 40 * 0.2 = 8 сек
                if not self._running:
                    break
                try:
                    cmd = self._control_q.get_nowait()
                    if isinstance(cmd, ControlEvent) and cmd.operation == 'stop':
                        self._running = False
                        break
                except Empty:
                    pass
                sleep(0.2)

        print(f'[{self.__class__.__name__}] завершение работы')

# %% [markdown]
# ### Инициализируем монитор и сущности

# %%
monitor = Monitor(monitor_events_queue)
control_system = ControlSystem(monitor_events_queue)
lights_gpio = LightsGPIO(monitor_events_queue)
self_diagnostics = SelfDiagnostics(monitor_events_queue) #Medium
city_connector = CitySystemConnector(monitor_events_queue) #Advanced

# %% [markdown]
# регистрируем очереди сущностей в мониторе

# %%
monitor.add_entity_queue(control_system.__class__.__name__, control_system.entity_queue())
monitor.add_entity_queue(lights_gpio.__class__.__name__, lights_gpio.entity_queue())
monitor.add_entity_queue(self_diagnostics.__class__.__name__, self_diagnostics.entity_queue()) #Medium
monitor.add_entity_queue(city_connector.__class__.__name__, city_connector.entity_queue()) #Advanced
# Out:
# [монитор] регистрируем сущность ControlSystem
# [монитор] регистрируем сущность LightsGPIO
# [монитор] регистрируем сущность SelfDiagnostics
# [монитор] регистрируем сущность CitySystemConnector

# %% [markdown]
# ### Запускаем всё

# %% [markdown]
# Ожидаемая последовательность событий
#
# ![Диаграмма последовательности вызовов](https://www.plantuml.com/plantuml/png/dPBVIiCm6CNlynIvdtk1NSZ02n4KXJr1w886-cUqcR0xgoBpIdoJLgqhtRg-mfStygJPM3js9OLyoPTpVia97ITQn7eU-6o6gZmr4w7c5r6euyYVB18j0ouIxhb6JpIHtZnMUd4JXKf7iPK5RjgJNQlx1vrStbtTMeNVhXZR0VdmV6yQ34QSQjhI5sNcWrE5QMrUgQHlysAUq7oZqcxyq1hbW6KxG8S5KWEBPHMe5MLeOBa6uHd4YWbVSs1JQg1OKktEF3ATSTI2Vk7Os6b6AupGerctn3uM5WWfn_OAxGRGr4OogTtktjCzmt3utyZ2q-fHQBb_JrSEv177oHigRB1E2ChOL1vxfPz8ZWjdBhv9ELn5Bw_vfFf4L2fFlZsEtkBBpNjxWH8mkyHWbbZbC1TCXbCsne1Vxmy0)

# %%
monitor.start()
control_system.start()
lights_gpio.start()
self_diagnostics.start() #Medium
city_connector.start() #Advanced
sleep(5)
# Out:
# [монитор] старт
# [ControlSystem] старт
# [ControlSystem] отправляем режим {'direction_1': 'green', 'direction_2': 'red'}
# [LightsGPIO] старт
# [SelfDiagnostics] старт
# [CitySystemConnector] старт
# [CitySystemConnector] отправляем команду: set_green_duration {"direction_1": 3, "direction_2": 7}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "green", "direction_2": "red"}')
# [монитор] проверяем конфигурацию {'direction_1': 'green', 'direction_2': 'red'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "green", "direction_2": "red"}')
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [ControlSystem] получена команда: set_green_duration {"direction_1": 3, "direction_2": 7}
# [ControlSystem] длительности изменены: d1=3, d2=7[LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "green", "direction_2": "red"}
#
# [LightsGPIO] новый режим: {"direction_1": "green", "direction_2": "red"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "green", "direction_2": "red"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "green", "direction_2": "red"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "green", "direction_2": "red"}
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow', 'direction_2': 'red'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow", "direction_2": "red"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow', 'direction_2': 'red'}
# [монитор] событие не разрешено политиками безопасности
# [ControlSystem] отправляем режим {'direction_1': 'red', 'direction_2': 'green'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "green"}')
# [монитор] проверяем конфигурацию {'direction_1': 'red', 'direction_2': 'green'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "green"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "red", "direction_2": "green"}
# [LightsGPIO] новый режим: {"direction_1": "red", "direction_2": "green"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "red", "direction_2": "green"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "red", "direction_2": "green"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "red", "direction_2": "green"}
# [SelfDiagnostics] статус: OK
# [CitySystemConnector] отправляем команду: set_system_mode {"mode": "yellow_blinking"}
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_system_mode', parameters='{"mode": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_system_mode', parameters='{"mode": "yellow_blinking"}')
# [ControlSystem] получена команда: set_system_mode {"mode": "yellow_blinking"}
# [ControlSystem] установлен специальный режим: yellow_blinking
# [ControlSystem] отправляем режим {'direction_1': 'red', 'direction_2': 'yellow'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "yellow"}')
# [монитор] проверяем конфигурацию {'direction_1': 'red', 'direction_2': 'yellow'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "red", "direction_2": "yellow"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "red", "direction_2": "yellow"}
# [LightsGPIO] новый режим: {"direction_1": "red", "direction_2": "yellow"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "red", "direction_2": "yellow"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "red", "direction_2": "yellow"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "red", "direction_2": "yellow"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [CitySystemConnector] отправляем команду: set_green_duration {"direction_1": 3, "direction_2": 7}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}[ControlSystem] получена команда: set_green_duration {"direction_1": 3, "direction_2": 7}
#
# [ControlSystem] длительности изменены: d1=3, d2=7[LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
#
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}[SelfDiagnostics] статус: OK
#
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [CitySystemConnector] отправляем команду: set_system_mode {"mode": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_system_mode', parameters='{"mode": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_system_mode', parameters='{"mode": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [ControlSystem] получена команда: set_system_mode {"mode": "yellow_blinking"}
# [ControlSystem] установлен специальный режим: yellow_blinking
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}[монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
#
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')[SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
#
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [CitySystemConnector] отправляем команду: set_green_duration {"direction_1": 3, "direction_2": 7}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [ControlSystem] получена команда: set_green_duration {"direction_1": 3, "direction_2": 7}
# [ControlSystem] длительности изменены: d1=3, d2=7
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}[монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
#
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [CitySystemConnector] отправляем команду: set_system_mode {"mode": "yellow_blinking"}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_system_mode', parameters='{"mode": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_system_mode', parameters='{"mode": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [ControlSystem] получена команда: set_system_mode {"mode": "yellow_blinking"}
# [ControlSystem] установлен специальный режим: yellow_blinking
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# ...
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')[ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
#
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [SelfDiagnostics] статус: OK
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [CitySystemConnector] отправляем команду: set_green_duration {"direction_1": 3, "direction_2": 7}
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] обрабатываем событие Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [монитор] отправляем запрос Event(source='CitySystemConnector', destination='ControlSystem', operation='set_green_duration', parameters='{"direction_1": 3, "direction_2": 7}')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [ControlSystem] получена команда: set_green_duration {"direction_1": 3, "direction_2": 7}
# [ControlSystem] длительности изменены: d1=3, d2=7
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] обрабатываем событие Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] проверяем конфигурацию {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [монитор] отправляем запрос Event(source='ControlSystem', destination='LightsGPIO', operation='set_mode', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [LightsGPIO] ControlSystem запрашивает изменение режима {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
# [LightsGPIO] новый режим: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}!
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='mode_changed', parameters='{"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}')
# [монитор] обрабатываем событие Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')[SelfDiagnostics] режим изменён: {"direction_1": "yellow_blinking", "direction_2": "yellow_blinking"}
#
# [монитор] отправляем запрос Event(source='LightsGPIO', destination='SelfDiagnostics', operation='diagnostic_status', parameters='OK')
# [SelfDiagnostics] статус: OK
# [ControlSystem] отправляем режим {'direction_1': 'yellow_blinking', 'direction_2': 'yellow_blinking'}
# [CitySystemConnector] завершение работы
# [монитор] проверяем запрос ControlEvent(operation='stop')[ControlSystem] завершение работы
#
# [монитор] завершение работы
# [LightsGPIO] получена команда остановки
# [LightsGPIO] завершение работы
# [SelfDiagnostics] завершение работы

# %% [markdown]
# ### Теперь останавливаем

# %%
control_system.stop()
lights_gpio.stop()
self_diagnostics.stop()
city_connector.stop()
monitor.stop()

control_system.join()
lights_gpio.join()
self_diagnostics.join()
city_connector.join()
monitor.join()

# %% [markdown]
# ## Заключение
#
# В этом блокноте продемонстрирован базовый функционал контролируемого изменения режима работы светофора.
#
# В примере не реализованы некоторые сущности и большая часть логики работы светофора, которую можно предположить по архитектурной диаграмме. Попробуйте сделать это самостоятельно!

# %% [markdown]
# ## Упражнения
#
# Уровень "Новичок"
#
# - в коде ControlSystem измените режим на недопустимый (два зелёных) и выполните все ячейки. Убедитесь, что монитор безопасности заблокировал сообщение, как нарушающее политику безопасности
# - измените политики безопасности так, чтобы был возможен режим "моргающий жёлтый" (yellow_blinking), переводящий перекрёсток в режим нерегулируемого
#
# Уровень "Средней сложности"
#
# - добавьте политики безопасности для доп. секций со стрелками (поворот налево или направо)
# - измените код сущностей, чтобы они не завершали работу после одного сообщения, а работали произвольное время (см. реализацию монитора безопасности)
# - реализуйте сущность само-диагностики (SelfDiagnostics) и отправку сообщений от LightsGPIO (необходимо доработать политики безопасности!)
#
# Уровень "Продвинутый"
#
# - измените код сущности ControlSystem, реализуйте смену режимов по таймеру (заданную длительность зелёного по каждому направлению)
# - реализуйте сущность CitySystemConnector, которая будет имитировать получение изменения режима, реализуйте взаимодействие CitySystemConnector и ControlSystem (понадобится доработать политики безопасности). Например, изменение длительности зелёного по направлениям или отключение светофора (перевод перекрёстка в режим нерегулируемого)
# - реализуйте передачу в компонент CitySystemConnector информации об исправности светофора (статус самодиагностики; текущий режим работы). В компоненте реализуйте вывод в виде сообщений о состоянии системы
